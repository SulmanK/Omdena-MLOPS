# %% [markdown]
# # Data cleaning and feature engineering
# ___________________________________________________________________________________________

# %% [markdown]
# ### Problem
#
# Solar energy is a renewable energy source that depends on the irradiation data parameters to be efficient. Therefore, before investing in a new solar plant, it is necessary to gather the most solar data possible.
#
# ### Acquisition of data
# 1) Process a "raw" satellite image of the location.
#
# 2) Use a collection of past satellite images at that location to create a "background"
#
# 3) Determine the cloud opacity - Decomposition of cloudy and cloud-free regions. Then, apply a 3D decomposition model to cloudy regions to characterize the thickness of each layer to sunlight.
#
# 4) Apply a modified version of the REST2 clear-sky radiation model, that allows us to use the latest global aerosol (dust, salt, smoke, etc.) and water vapor content to generate precise estimates of the solar radiation available to cloud-free regions.
#
# ### Purpose:
#
# Using the data collected, we want to predict solar irradiance.
#
# For more information on the data acquisition process, please head over to https://solcast.com/solar-radiation-data/inputs-and-algorithms/!

# %% [markdown]
# #### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# #### Read in Dataframe

# %%
# Read in dataframe using pandas
df = pd.read_csv('../datasets/raw/solar_ir_abj_60M_ny.csv')

# %% [markdown]
# #### Dataframe column names

# %%
# Print the column names
print(df.columns)

# Print the number of columns
print(len(df.columns))
# Out:
# Index(['PeriodEnd', 'PeriodStart', 'Period', 'AirTemp', 'Azimuth',
#        'CloudOpacity', 'DewpointTemp', 'Dhi', 'Dni', 'Ebh', 'Ghi',
#        'GtiFixedTilt', 'GtiTracking', 'PrecipitableWater', 'RelativeHumidity',
#        'SnowWater', 'SurfacePressure', 'WindDirection10m', 'WindSpeed10m',
#        'Zenith', 'AlbedoDaily'],
#       dtype='object')
# 21

# %% [markdown]
# We have 21 columns.

# %% [markdown]
# #### Feature selection

# %%
# Feature selection
df = df[['PeriodEnd', 'PeriodStart', 'AirTemp', 'Dhi', 'Dni', 'Ghi',
       'PrecipitableWater', 'RelativeHumidity', 'SurfacePressure',
       'WindDirection10m', 'WindSpeed10m']]

# %% [markdown]
# Label each sample with their respective periods and important weather data (selected by a subject matter expert)

# %% [markdown]
# #### Randomly display 10 rows

# %%
# Randomly display 10 rows
df.sample(10)
# Out:
#                    PeriodEnd           PeriodStart Period  AirTemp  Azimuth  \
# 21815   2009-06-28T01:00:00Z  2009-06-28T00:00:00Z  PT60M     21.7       58
# 15995   2008-10-28T13:00:00Z  2008-10-28T12:00:00Z  PT60M      7.0     -119
# 119715  2020-08-28T05:00:00Z  2020-08-28T04:00:00Z  PT60M     26.9        8
# 22319   2009-07-19T01:00:00Z  2009-07-19T00:00:00Z  PT60M     24.3       60
# 80318   2016-02-29T16:00:00Z  2016-02-29T15:00:00Z  PT60M     12.2     -149
# 77444   2015-11-01T22:00:00Z  2015-11-01T21:00:00Z  PT60M     17.2      112
# 99020   2018-04-18T22:00:00Z  2018-04-18T21:00:00Z  PT60M     11.4       96
# 8600    2007-12-25T10:00:00Z  2007-12-25T09:00:00Z  PT60M      1.3      -96
# 56620   2013-06-17T06:00:00Z  2013-06-17T05:00:00Z  PT60M     19.7       -9
# 49862   2012-09-08T16:00:00Z  2012-09-08T15:00:00Z  PT60M     24.6     -147
#
#         CloudOpacity  DewpointTemp  Dhi  Dni  Ebh  ...  GtiFixedTilt  \
# 21815            1.4          17.1    7    8    1  ...             7
# 15995           75.4           5.7   26    0    0  ...            24
# 119715          60.4          18.7    0    0    0  ...             0
# 22319            1.6          13.0    4    1    0  ...             4
# 80318           78.4           4.7  121    0    0  ...           111
# 77444           11.1          10.6   26   24    4  ...            36
# 99020            0.0           0.4   98  641  251  ...           338
# 8600             0.0          -4.3    0    0    0  ...             0
# 56620           26.1          17.0    0    0    0  ...             0
# 49862           26.8          22.1  377  209  159  ...           558
#
#         GtiTracking  PrecipitableWater  RelativeHumidity  SnowWater  \
# 21815             7               33.6              75.3        0.0
# 15995            26               19.4              91.4        0.0
# 119715            0               36.0              60.8        0.0
# 22319             4               21.2              49.1        0.0
# 80318           121               16.8              60.0        0.0
# 77444            33               14.7              64.8        0.0
# 99020           806               11.3              46.8        0.0
# 8600              0                8.3              66.4        0.0
# 56620             0               23.2              84.3        0.0
# 49862           563               38.9              86.0        0.0
#
#         SurfacePressure  WindDirection10m  WindSpeed10m  Zenith  AlbedoDaily
# 21815             997.1               327           3.3      91         0.11
# 15995             986.7               360           4.9      79         0.13
# 119715           1005.1               308           5.4     129         0.11
# 22319            1002.6               259           3.4      92         0.11
# 80318             993.6               236           6.5      54         0.11
# 77444            1002.8               243           4.8      87         0.10
# 99020             998.2               264           4.8      67         0.10
# 8600             1011.5               288           4.1     121         0.13
# 56620            1002.2               281           3.3     115         0.12
# 49862             997.5               185           7.2      40         0.10
#
# [10 rows x 21 columns]

# %% [markdown]
# #### Relabel column names

# %%
# Rename column names
old_names = ['PeriodEnd', 'PeriodStart', 'AirTemp', 'Dhi', 'Dni', 'Ghi','PrecipitableWater', 'RelativeHumidity',
             'SurfacePressure', 'WindDirection10m', 'WindSpeed10m'] 
new_names = ['PeriodEnd','PeriodStart','Temperature', 'DHI', 'DNI', 'Radiation', 'Precipitation', 'Humidity', 
             'Pressure', 'WindDirection', 'WindSpeed']
df.rename(columns = dict(zip(old_names, new_names)), inplace = True)

# %% [markdown]
# #### Display dataframe

# %%
# Display dataframe
df.head()
# Out:
#               PeriodEnd           PeriodStart Period  Temperature  Azimuth  \
# 0  2007-01-01T02:00:00Z  2007-01-01T01:00:00Z  PT60M          4.5       84
# 1  2007-01-01T03:00:00Z  2007-01-01T02:00:00Z  PT60M          4.6       72
# 2  2007-01-01T04:00:00Z  2007-01-01T03:00:00Z  PT60M          4.9       52
# 3  2007-01-01T05:00:00Z  2007-01-01T04:00:00Z  PT60M          5.4       20
# 4  2007-01-01T06:00:00Z  2007-01-01T05:00:00Z  PT60M          5.8      -22
#
#    CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  GtiFixedTilt  GtiTracking  \
# 0          61.6          -1.0    0    0    0  ...             0            0
# 1          61.8          -0.6    0    0    0  ...             0            0
# 2          59.0          -0.2    0    0    0  ...             0            0
# 3          76.9           0.2    0    0    0  ...             0            0
# 4          98.0           0.6    0    0    0  ...             0            0
#
#    Precipitation  Humidity  SnowWater  Pressure  WindDirection  WindSpeed  \
# 0           22.1      67.3        0.0    1017.3            163        3.3
# 1           24.2      68.8        0.0    1016.7            160        3.8
# 2           25.5      69.4        0.0    1015.9            159        4.3
# 3           26.2      69.2        0.0    1015.0            159        4.7
# 4           26.8      69.0        0.0    1014.2            159        5.0
#
#    Zenith  AlbedoDaily
# 0     133          0.1
# 1     144          0.1
# 2     154          0.1
# 3     161          0.1
# 4     161          0.1
#
# [5 rows x 21 columns]

# %% [markdown]
# Display a summary of the dataframe (show the datatype of each feature)

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131421 entries, 0 to 131420
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   PeriodEnd      131421 non-null  object
#  1   PeriodStart    131421 non-null  object
#  2   Period         131421 non-null  object
#  3   Temperature    131421 non-null  float64
#  4   Azimuth        131421 non-null  int64
#  5   CloudOpacity   131421 non-null  float64
#  6   DewpointTemp   131421 non-null  float64
#  7   DHI            131421 non-null  int64
#  8   DNI            131421 non-null  int64
#  9   Ebh            131421 non-null  int64
#  10  Radiation      131421 non-null  int64
#  11  GtiFixedTilt   131421 non-null  int64
#  12  GtiTracking    131421 non-null  int64
#  13  Precipitation  131421 non-null  float64
#  14  Humidity       131421 non-null  float64
#  15  SnowWater      131421 non-null  float64
#  16  Pressure       131421 non-null  float64
#  17  WindDirection  131421 non-null  int64
#  18  WindSpeed      131421 non-null  float64
#  19  Zenith         131421 non-null  int64
#  20  AlbedoDaily    131421 non-null  float64
# dtypes: float64(9), int64(9), object(3)
# memory usage: 21.1+ MB

# %% [markdown]
# #### Convert data types for prediction

# %%
# Convert features to appropriate datatypes for predictions
df['Radiation']     = df['Radiation'].astype(float)
df['Temperature']   = df['Temperature'].astype(float) # or int
df['Pressure']      = df['Pressure'].astype(float)
df['Humidity']      = df['Humidity'].astype(int) # or int
df['WindDirection'] = df['WindDirection'].astype(float)
df['WindSpeed']     = df['WindSpeed'].astype(float)
df['PeriodStart'] = pd.to_datetime(df['PeriodStart']).dt.to_period('T').dt.to_timestamp()
df['PeriodEnd'] = pd.to_datetime(df['PeriodEnd']).dt.to_period('T').dt.to_timestamp()

# %% [markdown]
# #### Display dataframe

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131421 entries, 0 to 131420
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   PeriodEnd      131421 non-null  datetime64[ns]
#  1   PeriodStart    131421 non-null  datetime64[ns]
#  2   Period         131421 non-null  object
#  3   Temperature    131421 non-null  float64
#  4   Azimuth        131421 non-null  int64
#  5   CloudOpacity   131421 non-null  float64
#  6   DewpointTemp   131421 non-null  float64
#  7   DHI            131421 non-null  int64
#  8   DNI            131421 non-null  int64
#  9   Ebh            131421 non-null  int64
#  10  Radiation      131421 non-null  float64
#  11  GtiFixedTilt   131421 non-null  int64
#  12  GtiTracking    131421 non-null  int64
#  13  Precipitation  131421 non-null  float64
#  14  Humidity       131421 non-null  int32
#  15  SnowWater      131421 non-null  float64
#  16  Pressure       131421 non-null  float64
#  17  WindDirection  131421 non-null  float64
#  18  WindSpeed      131421 non-null  float64
#  19  Zenith         131421 non-null  int64
#  20  AlbedoDaily    131421 non-null  float64
# dtypes: datetime64[ns](2), float64(10), int32(1), int64(7), object(1)
# memory usage: 20.6+ MB

# %% [markdown]
# #### Display top 6 rows

# %%
# Display top 6 rows
df.head(6)
# Out:
#             PeriodEnd         PeriodStart Period  Temperature  Azimuth  \
# 0 2007-01-01 02:00:00 2007-01-01 01:00:00  PT60M          4.5       84
# 1 2007-01-01 03:00:00 2007-01-01 02:00:00  PT60M          4.6       72
# 2 2007-01-01 04:00:00 2007-01-01 03:00:00  PT60M          4.9       52
# 3 2007-01-01 05:00:00 2007-01-01 04:00:00  PT60M          5.4       20
# 4 2007-01-01 06:00:00 2007-01-01 05:00:00  PT60M          5.8      -22
# 5 2007-01-01 07:00:00 2007-01-01 06:00:00  PT60M          6.2      -54
#
#    CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  GtiFixedTilt  GtiTracking  \
# 0          61.6          -1.0    0    0    0  ...             0            0
# 1          61.8          -0.6    0    0    0  ...             0            0
# 2          59.0          -0.2    0    0    0  ...             0            0
# 3          76.9           0.2    0    0    0  ...             0            0
# 4          98.0           0.6    0    0    0  ...             0            0
# 5          97.5           1.4    0    0    0  ...             0            0
#
#    Precipitation  Humidity  SnowWater  Pressure  WindDirection  WindSpeed  \
# 0           22.1        67        0.0    1017.3          163.0        3.3
# 1           24.2        68        0.0    1016.7          160.0        3.8
# 2           25.5        69        0.0    1015.9          159.0        4.3
# 3           26.2        69        0.0    1015.0          159.0        4.7
# 4           26.8        69        0.0    1014.2          159.0        5.0
# 5           27.6        71        0.0    1013.3          160.0        5.4
#
#    Zenith  AlbedoDaily
# 0     133          0.1
# 1     144          0.1
# 2     154          0.1
# 3     161          0.1
# 4     161          0.1
# 5     154          0.1
#
# [6 rows x 21 columns]

# %% [markdown]
# #### Create new features - year, month, and day

# %%
# Create new features(year, month, day) from start and end time of data collection  
df['YearPS'] = pd.to_datetime(df['PeriodStart']).dt.year
df['YearPE'] = pd.to_datetime(df['PeriodEnd']).dt.year

df['MonthPS'] = pd.to_datetime(df['PeriodStart']).dt.month
df['MonthPE'] = pd.to_datetime(df['PeriodEnd']).dt.month

df['HourPS'] = pd.to_datetime(df['PeriodStart']).dt.hour
df['HourPE'] = pd.to_datetime(df['PeriodEnd']).dt.hour

# %% [markdown]
# #### Display top 5 samples

# %%
# Display the top 5 samples
df.head(5)
# Out:
#             PeriodEnd         PeriodStart Period  Temperature  Azimuth  \
# 0 2007-01-01 02:00:00 2007-01-01 01:00:00  PT60M          4.5       84
# 1 2007-01-01 03:00:00 2007-01-01 02:00:00  PT60M          4.6       72
# 2 2007-01-01 04:00:00 2007-01-01 03:00:00  PT60M          4.9       52
# 3 2007-01-01 05:00:00 2007-01-01 04:00:00  PT60M          5.4       20
# 4 2007-01-01 06:00:00 2007-01-01 05:00:00  PT60M          5.8      -22
#
#    CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  WindDirection  WindSpeed  \
# 0          61.6          -1.0    0    0    0  ...          163.0        3.3
# 1          61.8          -0.6    0    0    0  ...          160.0        3.8
# 2          59.0          -0.2    0    0    0  ...          159.0        4.3
# 3          76.9           0.2    0    0    0  ...          159.0        4.7
# 4          98.0           0.6    0    0    0  ...          159.0        5.0
#
#    Zenith  AlbedoDaily  YearPS  YearPE  MonthPS  MonthPE  HourPS  HourPE
# 0     133          0.1    2007    2007        1        1       1       2
# 1     144          0.1    2007    2007        1        1       2       3
# 2     154          0.1    2007    2007        1        1       3       4
# 3     161          0.1    2007    2007        1        1       4       5
# 4     161          0.1    2007    2007        1        1       5       6
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Create a feature to identify time of sunrise

# %%
# Create a new feature for sunrise using the function below; fill time for sunrise
def time_to_sunrise(row):
    """
    A function for identifying time of sunrise.
    """
    value= 0
    if row['HourPS'] == 4 and row['HourPE'] == 5 and row['Radiation'] > 0:
        value= '05:00:00'
    elif row['HourPS'] == 5 and row['HourPE'] == 6 and row['Radiation'] > 0:
        value= '06:00:00'
    return value

# %% [markdown]
# #### Add the feature into the dataframe

# %%
# Create a new column using the function above
df['Sunrise'] = df.apply(time_to_sunrise, axis=1)
df.head(5)
# Out:
#             PeriodEnd         PeriodStart Period  Temperature  Azimuth  \
# 0 2007-01-01 02:00:00 2007-01-01 01:00:00  PT60M          4.5       84
# 1 2007-01-01 03:00:00 2007-01-01 02:00:00  PT60M          4.6       72
# 2 2007-01-01 04:00:00 2007-01-01 03:00:00  PT60M          4.9       52
# 3 2007-01-01 05:00:00 2007-01-01 04:00:00  PT60M          5.4       20
# 4 2007-01-01 06:00:00 2007-01-01 05:00:00  PT60M          5.8      -22
#
#    CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  WindSpeed  Zenith  \
# 0          61.6          -1.0    0    0    0  ...        3.3     133
# 1          61.8          -0.6    0    0    0  ...        3.8     144
# 2          59.0          -0.2    0    0    0  ...        4.3     154
# 3          76.9           0.2    0    0    0  ...        4.7     161
# 4          98.0           0.6    0    0    0  ...        5.0     161
#
#    AlbedoDaily  YearPS  YearPE  MonthPS  MonthPE  HourPS  HourPE  Sunrise
# 0          0.1    2007    2007        1        1       1       2        0
# 1          0.1    2007    2007        1        1       2       3        0
# 2          0.1    2007    2007        1        1       3       4        0
# 3          0.1    2007    2007        1        1       4       5        0
# 4          0.1    2007    2007        1        1       5       6        0
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Create a feature to identify time of sunset

# %%
# Create a new feature for sunset using the function below; fill time for sunset
def time_to_sunset(row):
    """
    A function for identifying time of sunset.
    """
    value= 0
    if row['HourPS'] == 17 and row['HourPE'] == 18 and row['Radiation']> 0:
        value= '18:00:00'
    elif row['HourPS'] == 18 and row['HourPE']== 19 and row['Radiation']> 0:
        value= '19:00:00'
    return value

# %% [markdown]
# #### Add the feature into dataframe

# %%
# Create a new column using the function above
df['Sunset'] = df.apply(time_to_sunset, axis=1)

# %% [markdown]
# #### Show unique values of sunset feature

# %%
# Unique values of sunset feature
df.Sunset.unique()
# Out:
# array([0, '18:00:00', '19:00:00'], dtype=object)

# %% [markdown]
# #### Summary of dataframe

# %%
# Show summary of our dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131421 entries, 0 to 131420
# Data columns (total 29 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   PeriodEnd      131421 non-null  datetime64[ns]
#  1   PeriodStart    131421 non-null  datetime64[ns]
#  2   Period         131421 non-null  object
#  3   Temperature    131421 non-null  float64
#  4   Azimuth        131421 non-null  int64
#  5   CloudOpacity   131421 non-null  float64
#  6   DewpointTemp   131421 non-null  float64
#  7   DHI            131421 non-null  int64
#  8   DNI            131421 non-null  int64
#  9   Ebh            131421 non-null  int64
#  10  Radiation      131421 non-null  float64
#  11  GtiFixedTilt   131421 non-null  int64
#  12  GtiTracking    131421 non-null  int64
#  13  Precipitation  131421 non-null  float64
#  14  Humidity       131421 non-null  int32
#  15  SnowWater      131421 non-null  float64
#  16  Pressure       131421 non-null  float64
#  17  WindDirection  131421 non-null  float64
#  18  WindSpeed      131421 non-null  float64
#  19  Zenith         131421 non-null  int64
#  20  AlbedoDaily    131421 non-null  float64
#  21  YearPS         131421 non-null  int64
#  22  YearPE         131421 non-null  int64
#  23  MonthPS        131421 non-null  int64
#  24  MonthPE        131421 non-null  int64
#  25  HourPS         131421 non-null  int64
#  26  HourPE         131421 non-null  int64
#  27  Sunrise        131421 non-null  int64
#  28  Sunset         131421 non-null  object
# dtypes: datetime64[ns](2), float64(10), int32(1), int64(14), object(2)
# memory usage: 28.6+ MB

# %% [markdown]
# #### Change interger values to datetime object

# %%
# Changing integer values to datetime format
df_new = df.loc[~((df['Radiation'] == 0) & (df['DNI'] == 0) & (df['DHI'] == 0)),:]

# %% [markdown]
# #### Display summary of dataframe

# %%
# Show summary of our dataframe
df_new.info()

# %% [markdown]
# #### Display 10 random samples

# %%
# display 10 random samples of the dataframe
df_new.sample(10)
# Out:
#                  PeriodEnd         PeriodStart Period  Temperature  Azimuth  \
# 64887  2014-05-27 17:00:00 2014-05-27 16:00:00  PT60M         27.4     -165
# 46772  2012-05-02 22:00:00 2012-05-02 21:00:00  PT60M         12.0       91
# 13862  2008-07-31 16:00:00 2008-07-31 15:00:00  PT60M         28.5     -133
# 22846  2009-08-10 00:00:00 2009-08-09 23:00:00  PT60M         23.7       73
# 99037  2018-04-19 15:00:00 2018-04-19 14:00:00  PT60M          6.5     -123
# 94212  2017-09-30 14:00:00 2017-09-30 13:00:00  PT60M         14.9     -122
# 93738  2017-09-10 20:00:00 2017-09-10 19:00:00  PT60M         21.2      125
# 49476  2012-08-23 14:00:00 2012-08-23 13:00:00  PT60M         23.2     -108
# 117225 2020-05-16 11:00:00 2020-05-16 10:00:00  PT60M         17.9      -72
# 16766  2008-11-29 16:00:00 2008-11-29 15:00:00  PT60M          4.5     -161
#
#         CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  Zenith  AlbedoDaily  \
# 64887           40.0          14.2  549    7    6  ...      21         0.11
# 46772           68.4           8.8  106    0    0  ...      65         0.11
# 13862            6.8          19.9  311  539  470  ...      30         0.11
# 22846           37.2          20.8   14    0    0  ...      85         0.11
# 99037           90.2           4.3   68    0    0  ...      44         0.10
# 94212            6.4           9.6  154  538  248  ...      62         0.11
# 93738           15.7           8.6  343  252  158  ...      50         0.11
# 49476           29.2          18.2  329   61   40  ...      54         0.11
# 117225          40.6          10.9   54    0    0  ...      82         0.11
# 16766           61.5          -2.8  165    0    0  ...      65         0.12
#
#         YearPS  YearPE  MonthPS  MonthPE  HourPS  HourPE  Sunrise  Sunset
# 64887     2014    2014        5        5      16      17        0       0
# 46772     2012    2012        5        5      21      22        0       0
# 13862     2008    2008        7        7      15      16        0       0
# 22846     2009    2009        8        8      23       0        0       0
# 99037     2018    2018        4        4      14      15        0       0
# 94212     2017    2017        9        9      13      14        0       0
# 93738     2017    2017        9        9      19      20        0       0
# 49476     2012    2012        8        8      13      14        0       0
# 117225    2020    2020        5        5      10      11        0       0
# 16766     2008    2008       11       11      15      16        0       0
#
# [10 rows x 29 columns]

# %% [markdown]
# #### Convert datetime column

# %%
# Convert datetime column of endperiod to just date
df_new['Date'] = pd.to_datetime(df_new['PeriodEnd']).dt.normalize()

# Convert the column (it's a string) to datetime type
dt_series = pd.to_datetime(df_new['Date'])

# Create datetime index passing the datetime series
dt_index = pd.DatetimeIndex(dt_series.values)

# Set new index
df_new1 = df_new.set_index(dt_index)
# Out:
# C:\Users\sulma\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Display first 5 rows

# %%
# Display first 5 rows
df_new1.head()
# Out:
#                      PeriodEnd         PeriodStart Period  Temperature  \
# 2007-01-01 2007-01-01 13:00:00 2007-01-01 12:00:00  PT60M          9.5
# 2007-01-01 2007-01-01 14:00:00 2007-01-01 13:00:00  PT60M         10.5
# 2007-01-01 2007-01-01 15:00:00 2007-01-01 14:00:00  PT60M         11.4
# 2007-01-01 2007-01-01 16:00:00 2007-01-01 15:00:00  PT60M         12.0
# 2007-01-01 2007-01-01 17:00:00 2007-01-01 16:00:00  PT60M         12.2
#
#             Azimuth  CloudOpacity  DewpointTemp  DHI  DNI  Ebh  ...  \
# 2007-01-01     -122          86.2           8.6    2    0    0  ...
# 2007-01-01     -133          90.6           9.8   11    0    0  ...
# 2007-01-01     -145          89.1          11.0   26    0    0  ...
# 2007-01-01     -158          85.3          11.7   49    0    0  ...
# 2007-01-01     -173          84.2          12.0   61    0    0  ...
#
#             AlbedoDaily  YearPS  YearPE  MonthPS  MonthPE  HourPS  HourPE  \
# 2007-01-01          0.1    2007    2007        1        1      12      13
# 2007-01-01          0.1    2007    2007        1        1      13      14
# 2007-01-01          0.1    2007    2007        1        1      14      15
# 2007-01-01          0.1    2007    2007        1        1      15      16
# 2007-01-01          0.1    2007    2007        1        1      16      17
#
#             Sunrise  Sunset       Date
# 2007-01-01        0       0 2007-01-01
# 2007-01-01        0       0 2007-01-01
# 2007-01-01        0       0 2007-01-01
# 2007-01-01        0       0 2007-01-01
# 2007-01-01        0       0 2007-01-01
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Summary of dataframe

# %%
# Display summary of dataframe
df_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 71885 entries, 2007-01-01 to 2021-12-28
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PeriodEnd      71885 non-null  datetime64[ns]
#  1   PeriodStart    71885 non-null  datetime64[ns]
#  2   Period         71885 non-null  object
#  3   Temperature    71885 non-null  float64
#  4   Azimuth        71885 non-null  int64
#  5   CloudOpacity   71885 non-null  float64
#  6   DewpointTemp   71885 non-null  float64
#  7   DHI            71885 non-null  int64
#  8   DNI            71885 non-null  int64
#  9   Ebh            71885 non-null  int64
#  10  Radiation      71885 non-null  float64
#  11  GtiFixedTilt   71885 non-null  int64
#  12  GtiTracking    71885 non-null  int64
#  13  Precipitation  71885 non-null  float64
#  14  Humidity       71885 non-null  int32
#  15  SnowWater      71885 non-null  float64
#  16  Pressure       71885 non-null  float64
#  17  WindDirection  71885 non-null  float64
#  18  WindSpeed      71885 non-null  float64
#  19  Zenith         71885 non-null  int64
#  20  AlbedoDaily    71885 non-null  float64
#  21  YearPS         71885 non-null  int64
#  22  YearPE         71885 non-null  int64
#  23  MonthPS        71885 non-null  int64
#  24  MonthPE        71885 non-null  int64
#  25  HourPS         71885 non-null  int64
#  26  HourPE         71885 non-null  int64
#  27  Sunrise        71885 non-null  int64
#  28  Sunset         71885 non-null  object
#  29  Date           71885 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(10), int32(1), int64(14), object(2)
# memory usage: 16.7+ MB

# %% [markdown]
# #### Tabulate the average for the solar and weather features

# %%
# Sample daily average for the solar and weather features
df_new1['Daily_radiation'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['Radiation'].mean()
df_new1['Daily_DNI'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['DNI'].mean()
df_new1['Daily_DHI'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['DHI'].mean()
df_new1['Daily_Temp'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['Temperature'].mean()
df_new1['Daily_Precip'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['Precipitation'].mean()
df_new1['Daily_Humidity'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['Humidity'].mean()
df_new1['Daily_Pressure'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['Pressure'].mean()
df_new1['Daily_WindDir'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['WindDirection'].mean()
df_new1['Daily_WindSpeed'] = df_new1.reset_index().groupby(pd.Grouper(key='Date', freq='1D'))['WindSpeed'].mean()

# %% [markdown]
# #### Summary of dataframe

# %%
# display a summary of our dataframe
df_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 71885 entries, 2007-01-01 to 2021-12-28
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PeriodEnd        71885 non-null  datetime64[ns]
#  1   PeriodStart      71885 non-null  datetime64[ns]
#  2   Period           71885 non-null  object
#  3   Temperature      71885 non-null  float64
#  4   Azimuth          71885 non-null  int64
#  5   CloudOpacity     71885 non-null  float64
#  6   DewpointTemp     71885 non-null  float64
#  7   DHI              71885 non-null  int64
#  8   DNI              71885 non-null  int64
#  9   Ebh              71885 non-null  int64
#  10  Radiation        71885 non-null  float64
#  11  GtiFixedTilt     71885 non-null  int64
#  12  GtiTracking      71885 non-null  int64
#  13  Precipitation    71885 non-null  float64
#  14  Humidity         71885 non-null  int32
#  15  SnowWater        71885 non-null  float64
#  16  Pressure         71885 non-null  float64
#  17  WindDirection    71885 non-null  float64
#  18  WindSpeed        71885 non-null  float64
#  19  Zenith           71885 non-null  int64
#  20  AlbedoDaily      71885 non-null  float64
#  21  YearPS           71885 non-null  int64
#  22  YearPE           71885 non-null  int64
#  23  MonthPS          71885 non-null  int64
#  24  MonthPE          71885 non-null  int64
#  25  HourPS           71885 non-null  int64
#  26  HourPE           71885 non-null  int64
#  27  Sunrise          71885 non-null  int64
#  28  Sunset           71885 non-null  object
#  29  Date             71885 non-null  datetime64[ns]
#  30  Daily_radiation  71885 non-null  float64
#  31  Daily_DNI        71885 non-null  float64
#  32  Daily_DHI        71885 non-null  float64
#  33  Daily_Temp       71885 non-null  float64
#  34  Daily_Precip     71885 non-null  float64
#  35  Daily_Humidity   71885 non-null  float64
#  36  Daily_Pressure   71885 non-null  float64
#  37  Daily_WindDir    71885 non-null  float64
#  38  Daily_WindSpeed  71885 non-null  float64
# dtypes: datetime64[ns](3), float64(19), int32(1), int64(14), object(2)
# memory usage: 21.7+ MB

# %% [markdown]
# #### Drop irrelevant features

# %%
# Drop irrelevant features
new_df= df_new1.drop(['PeriodStart', 'YearPS',
                      'HourPS', 'HourPE',
                      'Sunrise', 'Sunset',
                      'MonthPS', 'YearPE'], axis= 1)

# %% [markdown]
# #### Display top 10 rows

# %%
# Display first 10 rows
new_df.head(10)
# Out:
#                      PeriodEnd Period  Temperature  Azimuth  CloudOpacity  \
# 2007-01-01 2007-01-01 13:00:00  PT60M          9.5     -122          86.2
# 2007-01-01 2007-01-01 14:00:00  PT60M         10.5     -133          90.6
# 2007-01-01 2007-01-01 15:00:00  PT60M         11.4     -145          89.1
# 2007-01-01 2007-01-01 16:00:00  PT60M         12.0     -158          85.3
# 2007-01-01 2007-01-01 17:00:00  PT60M         12.2     -173          84.2
# 2007-01-01 2007-01-01 18:00:00  PT60M         12.4      172          84.6
# 2007-01-01 2007-01-01 19:00:00  PT60M         12.4      157          86.6
# 2007-01-01 2007-01-01 20:00:00  PT60M         12.2      144          72.0
# 2007-01-01 2007-01-01 21:00:00  PT60M         12.0      132          47.7
# 2007-01-01 2007-01-01 22:00:00  PT60M         11.7      122          37.2
#
#             DewpointTemp  DHI  DNI  Ebh  Radiation  ...       Date  \
# 2007-01-01           8.6    2    0    0        2.0  ... 2007-01-01
# 2007-01-01           9.8   11    0    0       11.0  ... 2007-01-01
# 2007-01-01          11.0   26    0    0       26.0  ... 2007-01-01
# 2007-01-01          11.7   49    0    0       49.0  ... 2007-01-01
# 2007-01-01          12.0   61    0    0       61.0  ... 2007-01-01
# 2007-01-01          12.2   60    0    0       60.0  ... 2007-01-01
# 2007-01-01          12.2   45    0    0       45.0  ... 2007-01-01
# 2007-01-01          12.0   60    0    0       60.0  ... 2007-01-01
# 2007-01-01          11.9   59    0    0       59.0  ... 2007-01-01
# 2007-01-01          11.4    9    0    0        9.0  ... 2007-01-01
#
#             Daily_radiation  Daily_DNI  Daily_DHI  Daily_Temp  Daily_Precip  \
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
#
#             Daily_Humidity  Daily_Pressure  Daily_WindDir  Daily_WindSpeed
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
# 2007-01-01            97.0          1001.9          210.4             4.54
#
# [10 rows x 31 columns]

# %% [markdown]
# #### Summary of dataframe

# %%
# Show a summary of the dataframe
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 71885 entries, 2007-01-01 to 2021-12-28
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PeriodEnd        71885 non-null  datetime64[ns]
#  1   Period           71885 non-null  object
#  2   Temperature      71885 non-null  float64
#  3   Azimuth          71885 non-null  int64
#  4   CloudOpacity     71885 non-null  float64
#  5   DewpointTemp     71885 non-null  float64
#  6   DHI              71885 non-null  int64
#  7   DNI              71885 non-null  int64
#  8   Ebh              71885 non-null  int64
#  9   Radiation        71885 non-null  float64
#  10  GtiFixedTilt     71885 non-null  int64
#  11  GtiTracking      71885 non-null  int64
#  12  Precipitation    71885 non-null  float64
#  13  Humidity         71885 non-null  int32
#  14  SnowWater        71885 non-null  float64
#  15  Pressure         71885 non-null  float64
#  16  WindDirection    71885 non-null  float64
#  17  WindSpeed        71885 non-null  float64
#  18  Zenith           71885 non-null  int64
#  19  AlbedoDaily      71885 non-null  float64
#  20  MonthPE          71885 non-null  int64
#  21  Date             71885 non-null  datetime64[ns]
#  22  Daily_radiation  71885 non-null  float64
#  23  Daily_DNI        71885 non-null  float64
#  24  Daily_DHI        71885 non-null  float64
#  25  Daily_Temp       71885 non-null  float64
#  26  Daily_Precip     71885 non-null  float64
#  27  Daily_Humidity   71885 non-null  float64
#  28  Daily_Pressure   71885 non-null  float64
#  29  Daily_WindDir    71885 non-null  float64
#  30  Daily_WindSpeed  71885 non-null  float64
# dtypes: datetime64[ns](2), float64(19), int32(1), int64(8), object(1)
# memory usage: 17.3+ MB

# %% [markdown]
# #### Drop all duplicate values except for the last value

# %%
# Dropping ALL duplicate values exceept the last value
new_df = new_df[~new_df.Date.duplicated(keep = 'last')]

# %% [markdown]
# #### Display the number of rows and columns

# %%
# show the number of rows and columns available
new_df.shape
# Out:
# (5476, 31)

# %% [markdown]
# #### Top 10 samples

# %%
# Show top 10 samples
new_df.head(10)
# Out:
#                      PeriodEnd Period  Temperature  Azimuth  CloudOpacity  \
# 2007-01-01 2007-01-01 22:00:00  PT60M         11.7      122          37.2
# 2007-01-02 2007-01-02 22:00:00  PT60M          6.0      122           0.0
# 2007-01-03 2007-01-03 22:00:00  PT60M          8.4      122           0.0
# 2007-01-04 2007-01-04 22:00:00  PT60M         10.8      122           0.0
# 2007-01-05 2007-01-05 22:00:00  PT60M         14.3      122          92.7
# 2007-01-06 2007-01-06 22:00:00  PT60M         16.4      122           0.0
# 2007-01-07 2007-01-07 22:00:00  PT60M          8.0      122          41.0
# 2007-01-08 2007-01-08 22:00:00  PT60M          7.6      122           0.3
# 2007-01-09 2007-01-09 22:00:00  PT60M          4.6      122           0.8
# 2007-01-10 2007-01-10 22:00:00  PT60M          0.4      122           0.0
#
#             DewpointTemp  DHI  DNI  Ebh  Radiation  ...       Date  \
# 2007-01-01          11.4    9    0    0        9.0  ... 2007-01-01
# 2007-01-02          -2.6    8  123   12       21.0  ... 2007-01-02
# 2007-01-03           2.1    9  109   11       21.0  ... 2007-01-03
# 2007-01-04           7.0   10  103   11       21.0  ... 2007-01-04
# 2007-01-05          13.8    2    0    0        2.0  ... 2007-01-05
# 2007-01-06          11.7   11  107   11       22.0  ... 2007-01-06
# 2007-01-07           2.3   13   33    4       18.0  ... 2007-01-07
# 2007-01-08           3.9   13  122   12       25.0  ... 2007-01-08
# 2007-01-09          -3.4   14  103   10       24.0  ... 2007-01-09
# 2007-01-10         -10.0   12  161   17       29.0  ... 2007-01-10
#
#             Daily_radiation  Daily_DNI  Daily_DHI  Daily_Temp  Daily_Precip  \
# 2007-01-01             38.2        0.0       38.2       11.63         31.83
# 2007-01-02            260.2      662.3       40.9        6.00          5.54
# 2007-01-03            251.7      589.0       47.3        6.51          6.79
# 2007-01-04            211.8      354.3       88.9        9.18         10.27
# 2007-01-05             42.7        0.0       42.7       13.88         34.87
# 2007-01-06            230.3      477.1       64.6       16.78         25.72
# 2007-01-07            255.3      593.1       52.9        7.90          9.57
# 2007-01-08             46.1       29.6       42.6       10.10         23.05
# 2007-01-09            199.7      242.0      127.0        3.91          6.93
# 2007-01-10            253.9      533.6       69.8        0.65          4.19
#
#             Daily_Humidity  Daily_Pressure  Daily_WindDir  Daily_WindSpeed
# 2007-01-01            97.0         1001.90          210.4             4.54
# 2007-01-02            57.4         1011.42          310.8             6.36
# 2007-01-03            67.2         1017.44          225.7             5.16
# 2007-01-04            81.0         1011.68          232.8             5.01
# 2007-01-05            91.3         1004.53          218.8             5.80
# 2007-01-06            89.4          996.20          242.4             7.02
# 2007-01-07            62.3         1016.62          188.9             1.82
# 2007-01-08            92.0          993.53          249.5             6.29
# 2007-01-09            53.0         1000.32          243.2             5.22
# 2007-01-10            51.5         1010.05          299.5             6.33
#
# [10 rows x 31 columns]

# %% [markdown]
# #### Display column names

# %%
# List out the column names
new_df.columns
# Out:
# Index(['PeriodEnd', 'Period', 'Temperature', 'Azimuth', 'CloudOpacity',
#        'DewpointTemp', 'DHI', 'DNI', 'Ebh', 'Radiation', 'GtiFixedTilt',
#        'GtiTracking', 'Precipitation', 'Humidity', 'SnowWater', 'Pressure',
#        'WindDirection', 'WindSpeed', 'Zenith', 'AlbedoDaily', 'MonthPE',
#        'Date', 'Daily_radiation', 'Daily_DNI', 'Daily_DHI', 'Daily_Temp',
#        'Daily_Precip', 'Daily_Humidity', 'Daily_Pressure', 'Daily_WindDir',
#        'Daily_WindSpeed'],
#       dtype='object')

# %% [markdown]
# #### Select pertinent features

# %%
# Select column features
final_df= new_df[['MonthPE', 'Date',
                  'Daily_Temp','Daily_Precip',
                  'Daily_Humidity', 'Daily_Pressure',
                  'Daily_WindDir','Daily_WindSpeed',
                  'Daily_DNI', 'Daily_DHI',
                  'Daily_radiation']]

# %% [markdown]
# #### Top 5 rows

# %%
# Print the first 5 rows
final_df.head()
# Out:
#             MonthPE       Date  Daily_Temp  Daily_Precip  Daily_Humidity  \
# 2007-01-01        1 2007-01-01       11.63         31.83            97.0
# 2007-01-02        1 2007-01-02        6.00          5.54            57.4
# 2007-01-03        1 2007-01-03        6.51          6.79            67.2
# 2007-01-04        1 2007-01-04        9.18         10.27            81.0
# 2007-01-05        1 2007-01-05       13.88         34.87            91.3
#
#             Daily_Pressure  Daily_WindDir  Daily_WindSpeed  Daily_DNI  \
# 2007-01-01         1001.90          210.4             4.54        0.0
# 2007-01-02         1011.42          310.8             6.36      662.3
# 2007-01-03         1017.44          225.7             5.16      589.0
# 2007-01-04         1011.68          232.8             5.01      354.3
# 2007-01-05         1004.53          218.8             5.80        0.0
#
#             Daily_DHI  Daily_radiation
# 2007-01-01       38.2             38.2
# 2007-01-02       40.9            260.2
# 2007-01-03       47.3            251.7
# 2007-01-04       88.9            211.8
# 2007-01-05       42.7             42.7

# %% [markdown]
# #### Display the shape

# %%
# Show the number of rows and column
final_df.shape
# Out:
# (5476, 11)

# %% [markdown]
# #### Export cleaned dataset

# %%
# Save cleaned dataset
final_df.to_csv('../datasets/cleaned/cleaned_solar_irradiation.csv')
